# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Fundamentals (Need) Exercises</span></div>

# %% [markdown]
# ### Exercise 1
# 1. Python is organized in **functions.** They can be in-built or user-defined.
# 2. The Python parser interprets the code line-by-line - i.e. it executes the code as it goes along. It stops at a faulty execution by throwing an error and does not proceed any further.
# 3. Python is case-sensitive.
# 4. Code readibility for developers in Python can be enhanced by using comment-lines that usually begin with a `#`.
# 5. Python is case-sensitive.
# 6. `=` - this is the assignment operator, which is **not** the same as `==` - which is a relational operator, checking equality.
# 7. Different blocks of code in Python are separated by _indents._
# 8. Anything within `''` or `""` is a string value (i.e. collection of English characters and letters). Anything else in English is usually considered a variable - a named memory location where data is stored.
# 9. Brackets are used for function calls and/or to store collections of data.
# 10. Additional utilities and operations can be incorporated into Python by `importing` modules/packages.
# 11. `.` - used to access attributes belonging to a particular package/module.

# %% [markdown]
# ### Exercise 2

# %%
from math import sqrt
x, y = 3, 4
z = int(sqrt((x**2 + (y**2))))
print(x,y,z)
# Out:
# 3 4 5

# %% [markdown]
# ### Exercise 3
#
# |**#**|**Term**|**Description**|
# |:--:|:--:|:--:|
# |1|Function|Block to organize and execute tasks in Python|
# |2|Arguments|Input data for a function that are passed to it during the function call statement|
# |3|Comments|Text added to Python code that is ignored by the interpreter, serving as notes or explanations|
# |4|Indentations|Spaces or tabs used at the beginning of lines to define the structure of Python code, indicating blocks of code within functions, loops, or conditional statements|
# |5|Packages|Collections of Python modules that extend the language's functionality|
# |6|`.`|Used to access attributes or methods of objects in Python|
# |7|`[]`|Defining a 1D list in Python|
# |8|`[[[]]]`|Represting multi-dimensional lists in Python|
# |9|`{}`|Define dictionaries (key-value) pairs for efficient data storing|

# %% [markdown]
# ### Exercise 4

# %%
5/2 #normal floating point division
5//2 #floor division giving an integer value
5%2 #mod operator returning the remainder
# Out:
# 1
